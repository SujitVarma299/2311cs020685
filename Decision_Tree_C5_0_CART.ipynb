# %% [markdown]
# <a href="https://colab.research.google.com/github/SujitVarma299/2311cs020685/blob/main/Decision_Tree_C5_0_CART.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.tree import DecisionTreeRegressor

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_name = "/content/iris.csv"

# %%
import pandas as pd
iris = pd.read_csv(file_name)

# %%
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
iris = iris.rename(columns={'sepal.length': 'sepal_length', 'sepal.width': 'sepal_width', 'petal.length': 'petal_length', 'petal.width': 'petal_width'})

# %%
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
iris = iris.rename(columns={"Species":"Flowers_types"})

# %%
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#     Flowers_types
# 0          setosa
# 1          setosa
# 2          setosa
# 3          setosa
# 4          setosa
# ...

# %%
label_encoder = preprocessing.LabelEncoder() # Now preprocessing is defined
iris['Flowers_types']=label_encoder.fit_transform(iris['Flowers_types'])
iris['Flowers_types']
iris[2:6]
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 2           3           4.7          3.2           1.3          0.2
# 3           4           4.6          3.1           1.5          0.2
# 4           5           5.0          3.6           1.4          0.2
# 5           6           5.4          3.9           1.7          0.4
#
#    Flowers_types
# 2              0
# 3              0
# 4              0
# 5              0

# %%
iris[2:5]
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 2           3           4.7          3.2           1.3          0.2
# 3           4           4.6          3.1           1.5          0.2
# 4           5           5.0          3.6           1.4          0.2
#
#    Flowers_types
# 2              0
# 3              0
# 4              0

# %%
x = iris.iloc[4:5]

# %%
x
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 4           5           5.0          3.6           1.4          0.2
#
#    Flowers_types
# 4              0

# %%
iris["Flowers_types"].unique()
# Out:
# array([0, 1, 2])

# %%
x = iris[['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width']]
y = iris['Flowers_types']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=40) # Use random_state instead of random_size

# %%
model = DecisionTreeRegressor()
model.fit(x_train, y_train)
model
# Out:
# DecisionTreeRegressor()

# %%
x = iris.iloc[:,0:4]
x
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length
# 0             1           5.1          3.5           1.4
# 1             2           4.9          3.0           1.4
# 2             3           4.7          3.2           1.3
# 3             4           4.6          3.1           1.5
# 4             5           5.0          3.6           1.4
# ..          ...           ...          ...           ...
# 145         146           6.7          3.0           5.2
# 146         147           6.3          2.5           5.0
# 147         148           6.5          3.0           5.2
# 148         149           6.2          3.4           5.4
# 149         150           5.9          3.0           5.1
#
# [150 rows x 4 columns]

# %%
y = iris['Flowers_types']

# %%
x
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length
# 0             1           5.1          3.5           1.4
# 1             2           4.9          3.0           1.4
# 2             3           4.7          3.2           1.3
# 3             4           4.6          3.1           1.5
# 4             5           5.0          3.6           1.4
# ..          ...           ...          ...           ...
# 145         146           6.7          3.0           5.2
# 146         147           6.3          2.5           5.0
# 147         148           6.5          3.0           5.2
# 148         149           6.2          3.4           5.4
# 149         150           5.9          3.0           5.1
#
# [150 rows x 4 columns]
